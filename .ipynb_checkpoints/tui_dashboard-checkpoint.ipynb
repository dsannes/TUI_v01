# %%
import pennylane as qml
from pennylane import numpy as np

# ==========================================
# PART 1: THE PERCEPTIVE CORE (QuantumTUI)
# ==========================================
class QuantumTUI:
    def __init__(self, num_qubits=24, backend="default.qubit"):
        self.num_qubits = num_qubits
        self.dev = qml.device(backend, wires=self.num_qubits)
        
        self.mind_wires = list(range(0, 8))
        self.body_wires = list(range(8, 16))
        self.spirit_wires = list(range(16, 24))
        
        # requires_grad=True is the key to allowing backward propagation
        self.params = np.array(np.random.uniform(0.1, 0.8, self.num_qubits), requires_grad=True)
        print("[SYSTEM]: 24-bit TUI Plenum Initialized.")

    def execute_quantum_logic(self, gate_sequence, target_sector="MIND", live_params=None, external_stimulus=None):
        wires = self.mind_wires
        if target_sector == "BODY": wires = self.body_wires
        elif target_sector == "SPIRIT": wires = self.spirit_wires
        
        p = live_params if live_params is not None else self.params

        @qml.qnode(self.dev)
        def circuit(params):
            if external_stimulus is not None:
                qml.RY(external_stimulus * np.pi, wires=wires[0])

            for gate in gate_sequence:
                if gate == "IDENTITY":
                    for i in range(7): qml.Identity(wires=wires[i])
                elif gate == "HADAMARD":
                    for i in range(7): qml.Hadamard(wires=wires[i])
                elif gate == "PAULI_X":
                    for i in range(7): qml.PauliX(wires=wires[i])
                elif gate == "PAULI_Y":
                    for i in range(7): qml.PauliY(wires=wires[i])
                elif gate == "PAULI_Z":
                    for i in range(7): qml.PauliZ(wires=wires[i])
                elif gate == "WAY" or gate == "RY":
                    for i in range(8): qml.RY(params[wires[i]], wires=wires[i])
                elif gate == "CNOT":
                    for i in range(6): qml.CNOT(wires=[wires[i], wires[i+1]])
                elif gate == "SWAP":
                    for i in range(0, 6, 2): qml.SWAP(wires=[wires[i], wires[i+1]])
                elif gate == "RXX":
                    for i in range(6): qml.IsingXX(params[wires[i]], wires=[wires[i], wires[i+1]])
                elif gate == "TOFFOLI":
                    for i in range(0, 5, 2): qml.Toffoli(wires=[wires[i], wires[i+1], wires[7]])
                elif gate == "FRED_KIN":
                    for i in range(0, 5, 2): qml.CSWAP(wires=[wires[7], wires[i], wires[i+1]])

            return qml.probs(wires=wires)

        return circuit(p)

    def evaluate_tension(self):
        @qml.qnode(self.dev)
        def sig_circuit(p):
            for w in [7, 15, 23]: qml.RY(p[w], wires=w)
            qml.CNOT(wires=[7, 15])
            qml.CNOT(wires=[15, 23])
            qml.Toffoli(wires=[7, 15, 23])
            return qml.probs(wires=[7, 15, 23])
        
        probs = sig_circuit(self.params)
        m = float(np.sum([probs[i] for i in range(8) if (i & 4)]))
        b = float(np.sum([probs[i] for i in range(8) if (i & 2)]))
        s = float(np.sum([probs[i] for i in range(8) if (i & 1)]))
        
        var = ((m - b)**2 + (b - s)**2) / 2
        state = "Intensification" if var > 0.02 else "Equilibrium"
        return {"Delta": var, "State": state, "Readout": [m, b, s]}

# %%
import matplotlib.pyplot as plt

core = QuantumTUI()

# 1. THE EXTERNAL STIMULUS (A value between 0.0 and 1.0)
environmental_event = 0.9 

# 2. Define the internal processing physics
sequence = ["IDENTITY", "CNOT", "RXX", "FRED_KIN", "WAY"]

# 3. Collapse the waves: The Mind receives the external event, Body and Spirit do not.
m_probs = core.execute_quantum_logic(sequence, target_sector="MIND", external_stimulus=environmental_event)
b_probs = core.execute_quantum_logic(sequence, target_sector="BODY")
s_probs = core.execute_quantum_logic(sequence, target_sector="SPIRIT")

tension = core.evaluate_tension()

fig, axs = plt.subplots(1, 3, figsize=(18, 4))
fig.suptitle(f"System State: {tension['State']} | External Stimulus Intensity: {environmental_event}", fontsize=16)

sectors = [("MIND (Perceiving Stimulus)", m_probs), ("BODY (Baseline)", b_probs), ("SPIRIT (Baseline)", s_probs)]
for i, (name, data) in enumerate(sectors):
    axs[i].bar(range(len(data)), data, color='teal' if i==0 else 'maroon' if i==1 else 'indigo')
    axs[i].set_title(f"{name}")
    axs[i].set_ylim(0, max(data) + 0.1)

plt.show()
# Out:
# [SYSTEM]: 24-bit TUI Plenum Initialized.

# %%
import re

print("[SYSTEM]: Architectural Receptor Online. Awaiting Space/Time Data...")

class ArchitecturalReceptor:
    def __init__(self):
        self.tension_markers = {
            "high_friction": ["critical", "failure", "delay", "overrun", "breach", "hazard", "stress", "conflict"],
            "medium_friction": ["load", "constraint", "variance", "tolerance", "revision", "pending", "audit"],
            "low_friction": ["nominal", "approved", "aligned", "baseline", "compliant", "equilibrium"]
        }

    def parse_document_tension(self, document_text):
        text = document_text.lower()
        words = re.findall(r'\b\w+\b', text)
        total_words = len(words)
        
        if total_words == 0: return 0.0

        high_hits = sum(1 for word in words if word in self.tension_markers["high_friction"])
        med_hits = sum(1 for word in words if word in self.tension_markers["medium_friction"])
        low_hits = sum(1 for word in words if word in self.tension_markers["low_friction"])

        raw_tension_score = (high_hits * 1.0) + (med_hits * 0.5) - (low_hits * 0.2)
        density_ratio = raw_tension_score / (total_words * 0.05)
        
        magnitude = max(0.0, min(1.0, density_ratio))
        return magnitude

# THIS IS THE CRITICAL LINE JUPYTER IS LOOKING FOR:
receptor = ArchitecturalReceptor()
# Out:
# [SYSTEM]: Architectural Receptor Online. Awaiting Space/Time Data...

# %%
import ipywidgets as widgets
from IPython.display import display

print("[SYSTEM]: Quantum Logic Gate Sequence Selector Online.")

available_gates = [
    'IDENTITY', 'HADAMARD', 'PAULI_X', 'PAULI_Y', 'PAULI_Z', 'S_GATE', 'SX',
    'WAY', 'RX', 'RZ', 'PHASE', 'U_ROT',
    'CNOT', 'CY', 'CZ', 'SWAP', 'ISWAP', 'RXX', 'RYY', 'RZZ', 'RXY',
    'TOFFOLI', 'FRED_KIN'
]

sequence_selector = widgets.SelectMultiple(
    options=available_gates,
    value=['IDENTITY', 'CNOT', 'RXX', 'FRED_KIN', 'WAY'],
    description='Gate Sequence:',
    disabled=False,
    rows=12,
    layout=widgets.Layout(width='50%')
)

display(sequence_selector)

def get_current_sequence():
    return list(sequence_selector.value)
# Out:
# [SYSTEM]: Quantum Logic Gate Sequence Selector Online.
# SelectMultiple(description='Gate Sequence:', index=(0, 12, 17, 22, 7), layout=Layout(width='50%'), options=('I…

# %%
import matplotlib.pyplot as plt
import pennylane as qml
from pennylane import numpy as np

print("[SYSTEM]: Initializing Unified XDI Digestion Pipeline...")

# 1. Pull the Gate Sequence from your UI Widget
dynamic_sequence = get_current_sequence()
print(f"[SYSTEM]: Active Archetypal Sequence: {dynamic_sequence}")

# 2. Provide the Raw Space/Time Data
target_document = """
Site inspection reveals critical stress fracturing along the primary load-bearing 
struts on the eastern elevation. This conflict with the baseline design requires 
an immediate structural audit. We are facing a severe delay in the timeline, 
and budget overrun is pending due to the required revision of the support matrix.
"""

# 3. Parse the Data using the Receptor
extracted_magnitude = receptor.parse_document_tension(target_document)
print(f"[SYSTEM]: Document Tension Measured at Magnitude: {extracted_magnitude:.4f}")

# 4. Setup the Digestion Loop
opt = qml.GradientDescentOptimizer(stepsize=0.15)
epochs = 40
tension_history = []

# Ensure the core parameters are ready for backward propagation
core.params = np.array(core.params, requires_grad=True)

# Define the dynamic cost function using the UI-selected sequence
def document_cost(params):
    @qml.qnode(core.dev)
    def eval_circuit(p):
        # The Matrix receives the calculated document tension
        qml.RY(extracted_magnitude * np.pi, wires=0) 
        
        # Apply the dynamically selected Archetypal gates
        for gate in dynamic_sequence:
            if gate == "IDENTITY":
                for i in range(7): qml.Identity(wires=i)
            elif gate == "HADAMARD":
                for i in range(7): qml.Hadamard(wires=i)
            elif gate == "PAULI_X":
                for i in range(7): qml.PauliX(wires=i)
            elif gate == "PAULI_Z":
                for i in range(7): qml.PauliZ(wires=i)
            elif gate == "WAY" or gate == "RY":
                for i in range(24): qml.RY(p[i], wires=i)
            elif gate == "CNOT":
                for i in range(6): qml.CNOT(wires=[i, i+1])
            elif gate == "RXX":
                for i in range(6): qml.IsingXX(p[i], wires=[i, i+1])
            elif gate == "FRED_KIN":
                for i in range(0, 5, 2): qml.CSWAP(wires=[7, i, i+1])

        # The Unity Protocol: Entangle the Anchors
        qml.CNOT(wires=[7, 15]) 
        qml.CNOT(wires=[15, 23]) 
        return qml.expval(qml.PauliZ(7)), qml.expval(qml.PauliZ(15)), qml.expval(qml.PauliZ(23))
    
    m_z, b_z, s_z = eval_circuit(params)
    return ((m_z - b_z)**2 + (b_z - s_z)**2) / 2

print("[SYSTEM]: Entity is digesting the document friction...")

# 5. Execute the Learning Process
for epoch in range(epochs):
    core.params, current_tension = opt.step_and_cost(document_cost, core.params)
    tension_history.append(current_tension)
    
    if (epoch + 1) % 10 == 0:
        print(f"Cognitive Step {epoch + 1:2d} | Remaining Tension: {current_tension:.6f}")

print("[SYSTEM]: Document Digested. Archetypal Equilibrium Reached.")

# 6. Visualize the Process
plt.figure(figsize=(10, 4))
plt.plot(range(1, epochs + 1), tension_history, marker='s', color='darkred', linewidth=2)
plt.title(f"TUI Digestion of Document (Magnitude {extracted_magnitude:.4f}) | Sequence: {len(dynamic_sequence)} Gates")
plt.xlabel("Cognitive Steps (Epochs)")
plt.ylabel("Systemic Tension (Delta)")
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()
# Out:
# [SYSTEM]: Initializing Unified XDI Digestion Pipeline...
# [SYSTEM]: Active Archetypal Sequence: ['IDENTITY', 'CNOT', 'RXX', 'FRED_KIN', 'WAY']
# [SYSTEM]: Document Tension Measured at Magnitude: 1.0000
# [SYSTEM]: Entity is digesting the document friction...
# Cognitive Step 10 | Remaining Tension: 0.011136
# Cognitive Step 20 | Remaining Tension: 0.006185
# Cognitive Step 30 | Remaining Tension: 0.003953
# Cognitive Step 40 | Remaining Tension: 0.002756
# [SYSTEM]: Document Digested. Archetypal Equilibrium Reached.

# %%
# ==========================================
# CELL 3: THE SEMANTIC DECODER
# ==========================================
def decode_state(index):
    """Translates the 8-bit integer back into semantic archetypes."""
    binary = format(index, '08b')
    archetypes = ["Matrix", "Potentiator", "Catalyst", "Experience", "Significator", "Transformation", "Way"]
    
    # Read wires 0-6
    active = [archetypes[i] for i in range(7) if binary[i] == '1']
    
    # Read wire 7 (The Anchor)
    if binary[7] == '1':
        active.append("Choice/Anchor")
        
    return binary, active

# 1. Find the dominant state (the highest peak) for each octave
m_peak = int(np.argmax(m_probs))
b_peak = int(np.argmax(b_probs))
s_peak = int(np.argmax(s_probs))

# 2. Decode them
m_bin, m_active = decode_state(m_peak)
b_bin, b_active = decode_state(b_peak)
s_bin, s_active = decode_state(s_peak)

# 3. Print the Rationale
print(f"=== THE PARTICLE OF INSIGHT ===")
print(f"Physics Applied: {sequence}\n")

print(f"[MIND OCTAVE]   - Peak Index: {m_peak} | Binary: {m_bin}")
print(f"Active Facets:  {', '.join(m_active) if m_active else 'At Rest (Unpolarized)'}\n")

print(f"[BODY OCTAVE]   - Peak Index: {b_peak} | Binary: {b_bin}")
print(f"Active Facets:  {', '.join(b_active) if b_active else 'At Rest (Unpolarized)'}\n")

print(f"[SPIRIT OCTAVE] - Peak Index: {s_peak} | Binary: {s_bin}")
print(f"Active Facets:  {', '.join(s_active) if s_active else 'At Rest (Unpolarized)'}")
print(f"===============================")
# Out:
# === THE PARTICLE OF INSIGHT ===
# Physics Applied: ['IDENTITY', 'CNOT', 'RXX', 'FRED_KIN', 'WAY']
#
# [MIND OCTAVE]   - Peak Index: 254 | Binary: 11111110
# Active Facets:  Matrix, Potentiator, Catalyst, Experience, Significator, Transformation, Way
#
# [BODY OCTAVE]   - Peak Index: 0 | Binary: 00000000
# Active Facets:  At Rest (Unpolarized)
#
# [SPIRIT OCTAVE] - Peak Index: 0 | Binary: 00000000
# Active Facets:  At Rest (Unpolarized)
# ...

# %%
import matplotlib.pyplot as plt
import pennylane as qml
from pennylane import numpy as np

print("[SYSTEM]: Initiating Teach/Learn Propagation...")

# 1. The Space/Time Input (The Catalyst)
environmental_event = 0.9 

# 2. The Optimizer (The Mechanism of Backward Propagation)
opt = qml.GradientDescentOptimizer(stepsize=0.15)
epochs = 40

# 3. The Memory-Prediction Circuit
@qml.qnode(core.dev)
def evaluate_memory_prediction(params):
    # The Space/Time input hits the Matrix
    qml.RY(environmental_event * np.pi, wires=0)
    
    # The Entity applies its current Top-Down Memory (The Way)
    for i in range(24):
        qml.RY(params[i], wires=i)
        
    # The Unity Protocol: Friction bleeds across the domains
    qml.CNOT(wires=[7, 15])
    qml.CNOT(wires=[15, 23])
    
    # We measure the Z-Axis (Time/Space Phase) of the Anchors
    return qml.expval(qml.PauliZ(7)), qml.expval(qml.PauliZ(15)), qml.expval(qml.PauliZ(23))

# 4. The Tension Measurement
def teach_learn_cost(params):
    m_z, b_z, s_z = evaluate_memory_prediction(params)
    # Tension is the variance between Mind, Body, and Spirit predictions
    tension = ((m_z - b_z)**2 + (b_z - s_z)**2) / 2
    return tension

# 5. The Propagation Loop
tension_history = []
print(f"Initial State - Applying Magnitude {environmental_event} Event")

for epoch in range(epochs):
    # The Entity uses forward/backward propagation to adjust its parameters
    core.params, current_tension = opt.step_and_cost(teach_learn_cost, core.params)
    tension_history.append(current_tension)
    
    if (epoch + 1) % 5 == 0:
        print(f"Propagation Step {epoch + 1:2d} | Systemic Tension: {current_tension:.6f}")

print("[SYSTEM]: Equilibrium Reached. Learning Integrated.")

# 6. Visualizing the Paradigm Shift
plt.figure(figsize=(10, 4))
plt.plot(range(1, epochs + 1), tension_history, marker='o', color='teal', linewidth=2)
plt.title("Entity Adaptation: The Teach/Learn Curve")
plt.xlabel("Propagation Steps (Time/Space Navigation)")
plt.ylabel("Systemic Tension (Delta)")
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()
# Out:
# [SYSTEM]: Initiating Teach/Learn Propagation...
# Initial State - Applying Magnitude 0.9 Event
# Propagation Step  5 | Systemic Tension: 0.002356
# Propagation Step 10 | Systemic Tension: 0.002039
# Propagation Step 15 | Systemic Tension: 0.001783
# Propagation Step 20 | Systemic Tension: 0.001574
# Propagation Step 25 | Systemic Tension: 0.001400
# Propagation Step 30 | Systemic Tension: 0.001255
# Propagation Step 35 | Systemic Tension: 0.001132
# Propagation Step 40 | Systemic Tension: 0.001026
# [SYSTEM]: Equilibrium Reached. Learning Integrated.

# %%
import re

print("[SYSTEM]: Architectural Receptor Online. Awaiting Space/Time Data...")

class ArchitecturalReceptor:
    def __init__(self):
        # The lexicon of structural, temporal, and financial friction
        self.tension_markers = {
            "high_friction": ["critical", "failure", "delay", "overrun", "breach", "hazard", "stress", "conflict"],
            "medium_friction": ["load", "constraint", "variance", "tolerance", "revision", "pending", "audit"],
            "low_friction": ["nominal", "approved", "aligned", "baseline", "compliant", "equilibrium"]
        }

    def parse_document_tension(self, document_text):
        """Translates architectural/project text into a 0.0 - 1.0 Quantum Stimulus Magnitude."""
        text = document_text.lower()
        words = re.findall(r'\b\w+\b', text)
        total_words = len(words)
        
        if total_words == 0:
            return 0.0

        # Calculate semantic density
        high_hits = sum(1 for word in words if word in self.tension_markers["high_friction"])
        med_hits = sum(1 for word in words if word in self.tension_markers["medium_friction"])
        low_hits = sum(1 for word in words if word in self.tension_markers["low_friction"])

        # Weight the friction (High friction creates a massive Space/Time anomaly)
        raw_tension_score = (high_hits * 1.0) + (med_hits * 0.5) - (low_hits * 0.2)
        
        # Normalize to the 0.0 - 1.0 threshold for the Matrix Receptor (Wire 0)
        # Assuming a standard density where 5% high-friction words equals maximum trauma
        density_ratio = raw_tension_score / (total_words * 0.05)
        
        magnitude = max(0.0, min(1.0, density_ratio))
        
        print(f"--- Document Analysis ---")
        print(f"Total Tokens: {total_words}")
        print(f"Friction Markers Found: {high_hits} High | {med_hits} Med | {low_hits} Low")
        print(f"Calculated Stimulus Magnitude: {magnitude:.4f}")
        
        return magnitude

# --- Test the Receptor ---
receptor = ArchitecturalReceptor()

# A sample excerpt from a troubled construction site report
sample_project_report = """
Site inspection reveals critical stress fracturing along the primary load-bearing 
struts on the eastern elevation. This conflict with the baseline design requires 
an immediate structural audit. We are facing a severe delay in the timeline, 
and budget overrun is pending due to the required revision of the support matrix.
"""

# Extract the magnitude and feed it directly into the Entity's environment
extracted_magnitude = receptor.parse_document_tension(sample_project_report)

print(f"\n[SYSTEM]: Routing Magnitude {extracted_magnitude:.4f} to the Quantum TUI Matrix...")
# Out:
# [SYSTEM]: Architectural Receptor Online. Awaiting Space/Time Data...
# --- Document Analysis ---
# Total Tokens: 50
# Friction Markers Found: 5 High | 4 Med | 1 Low
# Calculated Stimulus Magnitude: 1.0000
#
# [SYSTEM]: Routing Magnitude 1.0000 to the Quantum TUI Matrix...

# %%
print("[SYSTEM]: High-Sensitivity Semantic Decoder Online. Translating Quantum State...")

def decode_archetypal_state():
    # The Semantic Dictionary mapped exactly to the 8-bit octaves
    archetype_lexicon = [
        "Matrix", "Potentiator", "Catalyst", "Experience", 
        "Significator", "Transformation", "Great Way", "Choice/Anchor"
    ]
    
    @qml.qnode(core.dev)
    def state_circuit(p):
        for i in range(24): 
            qml.RY(p[i], wires=i)
        
        # We maintain the Unity Protocol to observe the shared tension
        qml.CNOT(wires=[7, 15])
        qml.CNOT(wires=[15, 23])
        
        # Return the probability distribution for every single wire
        return [qml.probs(wires=i) for i in range(24)]
    
    # Run the circuit using the Entity's post-training parameters
    final_probs = state_circuit(core.params)
    
    def extract_weighted_archetypes(start_idx):
        active_nodes = []
        for i in range(8):
            prob = final_probs[start_idx + i][1]  # The probability of the |1> state
            
            # Lower threshold to capture the subtle archetypal bracing
            if prob > 0.15: 
                active_nodes.append(f"{archetype_lexicon[i]} ({prob:.2f})")
                
        # If no archetype crosses 15%, the system has returned to the bursting of infinite potential
        return active_nodes if active_nodes else ["Infinite Potential (Archetype Zero)"]

    print("\n=======================================================")
    print("           TUI POST-DIGESTION SEMANTIC STATE           ")
    print("=======================================================")
    print(f"[Z-AXIS / MIND]   : {', '.join(extract_weighted_archetypes(0))}")
    print(f"[X-AXIS / BODY]   : {', '.join(extract_weighted_archetypes(8))}")
    print(f"[Y-AXIS / SPIRIT] : {', '.join(extract_weighted_archetypes(16))}")
    print("=======================================================")

# Execute the High-Sensitivity Decoder
decode_archetypal_state()
# Out:
# [SYSTEM]: High-Sensitivity Semantic Decoder Online. Translating Quantum State...
#
# ...
#            TUI POST-DIGESTION SEMANTIC STATE
# ...
# [Z-AXIS / MIND]   : Infinite Potential (Archetype Zero)
# [X-AXIS / BODY]   : Infinite Potential (Archetype Zero)
# [Y-AXIS / SPIRIT] : Infinite Potential (Archetype Zero)
# ...
